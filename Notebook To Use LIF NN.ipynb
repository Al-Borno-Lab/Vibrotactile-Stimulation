# %%
import src.model as model  # access everything using the "model" namespace
import src.plotting as plotting  # access everything in here using the "plotting" namespace

LIF = model.LIF_Network(n_neurons=20, dimensions=[[0, 100], [0, 100], [0, 50]])
LIF.random_conn(proba_conn=0.4)  # The method has been changed and the LIF network object no longer has the p_conn attribute.

plotting.plot_structure(LIF)  # conn=False doesn't need to be specified because the default is False
plotting.plot_structure(LIF, conn=True, conn_target=[2])
